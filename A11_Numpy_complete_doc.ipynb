# %% [markdown]
# ![1.png](attachment:4f86e08f-800e-44c3-a3a6-72b81f7537e1.png)

# %% [markdown]
# ##  Creating Numpy array

# %%
import numpy as np

# %%
np.array([2,4,56,422,32,1]) # 1D array
# Out:
# array([  2,   4,  56, 422,  32,   1])

# %%
a = np.array([2,4,56,422,32,1]) # 1D array
print(a)
# Out:
# [  2   4  56 422  32   1]

# %%
type(a)
# Out:
# numpy.ndarray

# %%
# 2D Array (Matrix)
new = np.array([[ 45,34,22,2,24,55,3,22]])
print(new)
# Out:
# [[45 34 22  2 24 55  3 22]]
